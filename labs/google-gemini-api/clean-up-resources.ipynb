# %% [markdown]
# ### 🗑️ Clean up resources
#
# When you're finished with the lab, you should remove all your deployed resources from Azure to avoid extra charges and keep your Azure subscription uncluttered.

# %%
import os, sys
sys.path.insert(1, '../../shared')  # add the shared directory to the Python path
import utils

deployment_name = os.path.basename(os.path.dirname(globals()['__vsc_ipynb_file__']))
resource_group = f"lab-{deployment_name}"

utils.cleanup_resources(deployment_name, resource_group_name=resource_group)
# Out:
# 👉🏽 🧹 Cleaning up resource group 'lab-google-gemini-api'...
# ⚙️ Running: az deployment group show --name google-gemini-api -g lab-google-gemini-api -o json
# ✅ Deployment retrieved ⌚ 16:16:34.936375 :2s]
# 👉🏽 Deployment provisioning state: Succeeded
# ⚙️ Running: az resource list -g lab-google-gemini-api --resource-type "microsoft.cognitiveservices/accounts/projects"
# ✅ Retrieved AI Foundry projects ⌚ 16:16:38.101131 :3s]
# ⚙️ Running: az cognitiveservices account list -g lab-google-gemini-api
# ✅ Listed CognitiveService accounts ⌚ 16:16:41.097274 :2s]
# ⚙️ Running:  az apim list -g lab-google-gemini-api
# ✅ Listed APIM resources ⌚ 16:16:43.891918 :2s]
# 👉🏽 Deleting and purging API Management 'apim-iimgh5xpv42em' in resource group 'lab-google-gemini-api'...
# ⚙️ Running: az apim delete -n apim-iimgh5xpv42em -g lab-google-gemini-api -y
# ✅ API Management 'apim-iimgh5xpv42em' deleted ⌚ 16:17:47.368575 :3s]
# ⚙️ Running: az apim deletedservice purge --service-name apim-iimgh5xpv42em --location "East US 2"
# ✅ API Management 'apim-iimgh5xpv42em' purged ⌚ 16:19:14.896826 :27s]
# ⚙️ Running: az keyvault list -g lab-google-gemini-api
# ✅ Listed Key Vault resources ⌚ 16:19:17.208028 :2s]
# 👉🏽 🧹 Deleting resource group 'lab-google-gemini-api'... ⌚ 16:19:17.208802
# ⚙️ Running: az group delete --name lab-google-gemini-api -y
# ✅ Resource group 'lab-google-gemini-api' deleted ⌚ 16:20:23.496319 :6s]
# 👉🏽 🧹 Cleanup completed. ⌚ 16:20:23.497065
