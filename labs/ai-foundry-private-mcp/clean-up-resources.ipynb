# %% [markdown]
# ### 🗑️ Clean up resources
#
# When you're finished with the lab, you should remove all your deployed resources from Azure to avoid extra charges and keep your Azure subscription uncluttered.

# %%
import os, sys
sys.path.insert(1, '../../shared')  # add the shared directory to the Python path
import utils

deployment_name = os.path.basename(os.path.dirname(globals()['__vsc_ipynb_file__']))
utils.cleanup_resources(deployment_name)
# Out:
# 👉🏽 🧹 Cleaning up resource group 'lab-notebooks'...
# ⚙️ Running: az deployment group show --name notebooks -g lab-notebooks -o json
# ✅ Deployment retrieved ⌚ 11:01:56.667990 :5s]
# 👉🏽 Deployment provisioning state: Succeeded
# ⚙️ Running: az resource list -g lab-notebooks --resource-type "microsoft.cognitiveservices/accounts/projects"
# ✅ Retrieved AI Foundry projects ⌚ 11:02:00.566280 :3s]
# 👉🏽 Deleting AI Foundry project 'foundryorileqqs2tzlo/foundry-project-orileqqs2tzlo' in resource group 'lab-notebooks'...
# ⚙️ Running: az resource delete --ids "/subscriptions/06d043e2-5a2e-46bf-bf48-fffee525f377/resourceGroups/lab-notebooks/providers/Microsoft.CognitiveServices/accounts/foundryorileqqs2tzlo/projects/foundry-project-orileqqs2tzlo"
# ✅ AI Foundry project 'foundryorileqqs2tzlo/foundry-project-orileqqs2tzlo' deleted ⌚ 11:02:40.586080 :40s]
# ⚙️ Running: az cognitiveservices account list -g lab-notebooks
# ✅ Listed CognitiveService accounts ⌚ 11:02:44.020599 :3s]
# 👉🏽 Deleting and purging Cognitive Service Account 'foundryorileqqs2tzlo' in resource group 'lab-notebooks'...
# ⚙️ Running: az cognitiveservices account delete -g lab-notebooks -n foundryorileqqs2tzlo
# ✅ Cognitive Services 'foundryorileqqs2tzlo' deleted ⌚ 11:03:09.880281 :25s]
# ⚙️ Running: az cognitiveservices account purge -g lab-notebooks -n foundryorileqqs2tzlo -l "eastus2"
# ✅ Cognitive Services 'foundryorileqqs2tzlo' purged ⌚ 11:04:12.037730 :2s]
# ⚙️ Running:  az apim list -g lab-notebooks
# ✅ Listed APIM resources ⌚ 11:04:16.341272 :4s]
# 👉🏽 Deleting and purging API Management 'apim-orileqqs2tzlo' in resource group 'lab-notebooks'...
# ⚙️ Running: az apim delete -n apim-orileqqs2tzlo -g lab-notebooks -y
# ✅ API Management 'apim-orileqqs2tzlo' deleted ⌚ 11:05:41.649179 :25s]
# ⚙️ Running: az apim deletedservice purge --service-name apim-orileqqs2tzlo --location "East US 2"
# ✅ API Management 'apim-orileqqs2tzlo' purged ⌚ 11:07:13.058509 :31s]
# ⚙️ Running: az keyvault list -g lab-notebooks
# ✅ Listed Key Vault resources ⌚ 11:07:17.445335 :4s]
# 👉🏽 Deleting and purging Key Vault 'kv-orileqqs2tzlo' in resource group 'lab-notebooks'...
# ⚙️ Running: az keyvault delete -n kv-orileqqs2tzlo -g lab-notebooks
# ✅ Key Vault 'kv-orileqqs2tzlo' deleted ⌚ 11:07:26.437964 :8s]
# ⚙️ Running: az keyvault purge -n kv-orileqqs2tzlo --location "eastus2"
# ✅ Key Vault 'kv-orileqqs2tzlo' purged ⌚ 11:17:33.311500 :6s]
# 👉🏽 🧹 Deleting resource group 'lab-notebooks'... ⌚ 11:17:33.312518
# ⚙️ Running: az group delete --name lab-notebooks -y
