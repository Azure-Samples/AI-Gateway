# %% [markdown]
# # Clean Up Resources
#
# This notebook removes the resource group created for the `ai-foundry-hosted-agents-custom-framework` lab.

# %%
import shutil
import subprocess
import sys

_az = (
    shutil.which("az")
    or shutil.which("az.cmd")
    or r"C:\Program Files\Microsoft SDKs\Azure\CLI2\wbin\az.CMD"
 )

if not _az:
    raise FileNotFoundError(
        "Azure CLI executable was not found. Install Azure CLI or add it to PATH."
    )

def run(cmd):
    if cmd and cmd[0] == "az":
        cmd = [_az] + cmd[1:]
    print("\n$ " + " ".join(cmd))
    result = subprocess.run(cmd, capture_output=True, text=True)
    if result.stdout:
        print(result.stdout)
    if result.returncode != 0:
        if result.stderr:
            print(result.stderr)
        raise RuntimeError(f"Command failed: {result.returncode}")

subscription_id = "baba41cf-c01d-4a55-b6c5-ca494b802be5"
resource_group = "rg-aigw-hosted-custom-framework"

# %%
# Delete lab resources
run(["az", "account", "set", "--subscription", subscription_id])
run(["az", "group", "delete", "--name", resource_group, "--yes", "--no-wait"])
print("Deletion started. Use az group show to verify completion.")
# Out:
# $ az account set --subscription baba41cf-c01d-4a55-b6c5-ca494b802be5
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Delete lab resources
# ----> 2 run(['az', 'account', 'set', '--subscription', subscription_id])
#       3 run(['az', 'group', 'delete', '--name', resource_group, '--yes', '--no-wait'])
#       4 print('Deletion started. Use az group show to verify completion.')
#
# Cell In[1], line 5, in run(cmd)
#       3 def run(cmd):
#       4     print('\n$ ' + ' '.join(cmd))
# ----> 5     result = subprocess.run(cmd, capture_output=True, text=True)
#       6     if result.stdout:
#       7         print(result.stdout)
#       8     if result.returncode != 0:
#
# File c:\Users\ollisgeorge\AppData\Local\Programs\Python\Python312-x64\Lib\subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
# ...
