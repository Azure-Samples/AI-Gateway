# %% [markdown]
# ### 🗑️ Clean up resources
#
# Delete the lab resource group when you are finished to stop charges for API Management, Microsoft Foundry, Container Apps, Container Registry, API Center, and monitoring resources.

# %%
import os
import sys

sys.path.insert(1, "../../shared")
import utils

deployment_name = os.path.basename(os.path.dirname(globals()["__vsc_ipynb_file__"]))
resource_group_name = f"lab-{deployment_name}"

utils.cleanup_resources(deployment_name, resource_group_name=resource_group_name)
